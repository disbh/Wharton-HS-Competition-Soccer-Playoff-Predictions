# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# Load the data
data_path = os.path.join(os.path.dirname(os.getcwd()), 'data', 'NSL_regular_season_data_2.csv')
print(data_path)
data = pd.read_csv(data_path)
# Out:
# /workspaces/Wharton-HS-Competition-Soccer-Playoff-Predictions/data/NSL_regular_season_data_2.csv

# %%
# Visualize the data
data
# Out:
#            game_id HomeTeam AwayTeam  HomeScore  AwayScore  Home_xG  Away_xG  \
# 0     game_2023_94      TUC      ALB          1          3     2.52     2.00
# 1    game_2023_341      MOB      ALB          3          1     0.46     0.99
# 2    game_2023_442      CHM      ALB          0          1     1.62     1.16
# 3     game_2023_50      SAS      ALB          2          1     1.53     0.55
# 4    game_2023_389      FOR      ALB          0          2     2.15     1.13
# ..             ...      ...      ...        ...        ...      ...      ...
# 471   game_2023_81      TUC      WIC          2          1     2.72     0.38
# 472   game_2023_36      DOV      WIC          0          2     1.11     1.34
# 473  game_2023_269      SFS      WIC          1          1     2.84     0.30
# 474  game_2023_298      ALB      WIC          2          3     2.61     2.09
# 475  game_2023_428      ANC      WIC          1          0     0.94     0.27
#
#      Home_shots  Away_shots  Home_corner  Away_corner  Home_PK_Goal  \
# 0            13          15            3            4             0
# 1            11           8            3            6             0
# 2            16          13            1            7             0
# 3            20           2            6            1             0
# 4            18          13            2            0             0
# ..          ...         ...          ...          ...           ...
# 471          16           8            8            2             0
# 472           9          13            7            4             0
# 473          26           2            8            6             0
# 474          12          17            7            4             0
# 475          15          16            3            2             0
#
#      Away_PK_Goal  Home_PK_shots  Away_PK_shots  Home_ToP
# 0               0              1              0      0.53
# 1               0              0              0      0.56
# 2               0              0              0      0.52
# 3               0              0              0      0.49
# 4               0              0              0      0.71
# ..            ...            ...            ...       ...
# 471             0              0              0      0.33
# 472             0              0              0      0.31
# 473             0              0              0      0.54
# 474             0              0              0      0.43
# 475             0              0              0      0.44
#
# [476 rows x 16 columns]

# %%
# Get all the games that involve team.
team_name = 'OAK'
team_home = data[data['HomeTeam'] == team_name]
team_away = data[data['AwayTeam'] == team_name]
team = pd.concat([team_home, team_away], axis=0)

# Create a new column called 'Winner' that contains 1 if team wins, 0 if team loses
team['is_home'] = np.where(team['HomeTeam'].eq(team_name), 1, 0)
team['Winner'] = np.where(team['is_home'], team['HomeScore'] > team['AwayScore'], team['AwayScore'] > team['HomeScore'])

# Redefine each of the home and away games to be relative to team
team['curr_xG'] = np.where(team['is_home'], team['Home_xG'], team['Away_xG'])
team['opp_xG'] = np.where(team['is_home'], team['Away_xG'], team['Home_xG'])
team['curr_shots'] = np.where(team['is_home'], team['Home_shots'], team['Away_shots'])
team['opp_shots'] = np.where(team['is_home'], team['Away_shots'], team['Home_shots'])
team['curr_corner'] = np.where(team['is_home'], team['Home_corner'], team['Away_corner'])
team['opp_corner'] = np.where(team['is_home'], team['Away_corner'], team['Home_corner'])
team['curr_PK_Goal'] = np.where(team['is_home'], team['Home_PK_Goal'], team['Away_PK_Goal'])
team['opp_PK_Goal'] = np.where(team['is_home'], team['Away_PK_Goal'], team['Home_PK_Goal'])
team['curr_PK_shots'] = np.where(team['is_home'], team['Home_PK_shots'], team['Away_PK_shots'])
team['opp_PK_shots'] = np.where(team['is_home'], team['Away_PK_shots'], team['Home_PK_shots'])
team['possesion'] = np.where(team['is_home'], team['Home_ToP'], 1 - team['Home_ToP'])

# Drop all home and away columns
team = team.drop(['game_id', 'HomeTeam', 'AwayTeam', 'HomeScore', 'AwayScore', 'Home_xG', 'Away_xG',
                  'Home_shots', 'Away_shots', 'Home_corner', 'Away_corner', 'Home_PK_Goal', 'Away_PK_Goal',
                  'Home_PK_shots', 'Away_PK_shots', 'Home_ToP'], axis=1)

team.head()
# Out:
#      is_home  Winner  curr_xG  opp_xG  curr_shots  opp_shots  curr_corner  \
# 11         1   False     1.60    1.43          12         19            7
# 27         1   False     1.43    1.66          21         10            4
# 60         1   False     1.05    0.98          12         14            3
# 79         1   False     0.72    1.39           4         18            5
# 125        1   False     0.98    1.48          16         19            7
#
#      opp_corner  curr_PK_Goal  opp_PK_Goal  curr_PK_shots  opp_PK_shots  \
# 11            5             0            0              0             0
# 27            2             0            0              0             0
# 60            2             0            0              0             0
# 79            4             0            0              0             0
# 125           3             0            0              0             0
#
#      possesion
# 11        0.47
# 27        0.43
# 60        0.62
# 79        0.54
# 125       0.60

# %%
# Visualize the mean and spread of the data
team.describe()
# Out:
#          is_home    curr_xG     opp_xG  curr_shots  opp_shots  curr_corner  \
# count  34.000000  34.000000  34.000000   34.000000  34.000000    34.000000
# mean    0.500000   1.258235   1.084412   13.205882  12.441176     4.735294
# std     0.507519   0.716107   0.589500    5.682399   6.150591     2.643561
# min     0.000000   0.170000   0.220000    1.000000   2.000000     0.000000
# 25%     0.000000   0.720000   0.672500   11.000000   9.000000     2.250000
# 50%     0.500000   1.150000   1.000000   13.500000  11.500000     4.000000
# 75%     1.000000   1.647500   1.420000   16.750000  14.000000     7.000000
# max     1.000000   2.780000   2.860000   23.000000  28.000000    11.000000
#
#        opp_corner  curr_PK_Goal  opp_PK_Goal  curr_PK_shots  opp_PK_shots  \
# count   34.000000     34.000000         34.0      34.000000     34.000000
# mean     4.823529      0.029412          0.0       0.205882      0.147059
# std      2.656845      0.171499          0.0       0.478597      0.359491
# min      0.000000      0.000000          0.0       0.000000      0.000000
# 25%      3.000000      0.000000          0.0       0.000000      0.000000
# 50%      5.000000      0.000000          0.0       0.000000      0.000000
# 75%      6.000000      0.000000          0.0       0.000000      0.000000
# max     11.000000      1.000000          0.0       2.000000      1.000000
#
#        possesion
# count  34.000000
# mean    0.464118
# std     0.083996
# min     0.320000
# 25%     0.412500
# 50%     0.455000
# 75%     0.522500
# max     0.620000

# %%
# Split the data into a feature matrix and a target vector
X = team
y = team['Winner']

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# Make sure that the data is balanced
X_train = pd.DataFrame(X_train, columns=team.columns)
X_test = pd.DataFrame(X_test, columns=team.columns)
print(X_train['Winner'].value_counts())

# Resample the data
X_train_0 = X_train[X_train['Winner'] == 0]
X_train_1 = X_train[X_train['Winner'] == 1]
samples = 100
X_train_0_resampled = X_train_0.sample(samples, replace=True)
X_train_1_resampled = X_train_1.sample(samples, replace=True)
X_train = pd.concat([X_train_0_resampled, X_train_1_resampled], axis=0)
print(X_train['Winner'].value_counts())

X_test_0 = X_test[X_test['Winner'] == 0]
X_test_1 = X_test[X_test['Winner'] == 1]
samples = 100
X_test_0_resampled = X_test_0.sample(samples, replace=True)
X_test_1_resampled = X_test_1.sample(samples, replace=True)
X_test = pd.concat([X_test_0_resampled, X_test_1_resampled], axis=0)

y_train = X_train['Winner'].values
y_test = X_test['Winner'].values 

# Redefine the index of the data'
X_train = X_train.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)
# Out:
# False    16
# True      9
# Name: Winner, dtype: int64
# False    100
# True     100
# Name: Winner, dtype: int64

# %%
from pycaret.classification import ClassificationExperiment
s = ClassificationExperiment()
s.setup(team, target = 'Winner', session_id = 123)
# Out:
# <style type="text/css">
# #T_78dfc_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_78dfc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78dfc_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_78dfc_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78dfc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_78dfc_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_78dfc_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_78dfc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_78dfc_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_78dfc_row1_col1" class="data row1 col1" >Winner</td>
#     </tr>
#     <tr>
#       <th id="T_78dfc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_78dfc_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_78dfc_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_78dfc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_78dfc_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_78dfc_row3_col1" class="data row3 col1" >(34, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_78dfc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_78dfc_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_78dfc_row4_col1" class="data row4 col1" >(34, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_78dfc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_78dfc_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_78dfc_row5_col1" class="data row5 col1" >(23, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_78dfc_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_78dfc_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_78dfc_row6_col1" class="data row6 col1" >(11, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_78dfc_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_78dfc_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_78dfc_row7_col1" class="data row7 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_78dfc_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_78dfc_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_78dfc_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_78dfc_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_78dfc_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_78dfc_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_78dfc_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_78dfc_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_78dfc_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_78dfc_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_78dfc_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_78dfc_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_78dfc_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_78dfc_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_78dfc_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_78dfc_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_78dfc_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_78dfc_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_78dfc_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_78dfc_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_78dfc_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_78dfc_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_78dfc_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_78dfc_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_78dfc_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_78dfc_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_78dfc_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_78dfc_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_78dfc_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_78dfc_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_78dfc_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_78dfc_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_78dfc_row18_col1" class="data row18 col1" >fd61</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = s.compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             15:41:04
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
# <style type="text/css">
# #T_3b736 th {
#   text-align: left;
# }
# #T_3b736_row0_col0, #T_3b736_row0_col3, #T_3b736_row0_col4, #T_3b736_row0_col5, #T_3b736_row1_col0, #T_3b736_row1_col1, #T_3b736_row1_col2, #T_3b736_row1_col6, #T_3b736_row2_col0, #T_3b736_row2_col1, #T_3b736_row2_col2, #T_3b736_row2_col4, #T_3b736_row2_col5, #T_3b736_row2_col6, #T_3b736_row2_col7, #T_3b736_row3_col0, #T_3b736_row3_col1, #T_3b736_row3_col2, #T_3b736_row3_col3, #T_3b736_row3_col4, #T_3b736_row3_col5, #T_3b736_row3_col6, #T_3b736_row3_col7, #T_3b736_row4_col0, #T_3b736_row4_col1, #T_3b736_row4_col2, #T_3b736_row4_col3, #T_3b736_row4_col4, #T_3b736_row4_col5, #T_3b736_row4_col6, #T_3b736_row4_col7, #T_3b736_row5_col0, #T_3b736_row5_col1, #T_3b736_row5_col2, #T_3b736_row5_col3, #T_3b736_row5_col4, #T_3b736_row5_col5, #T_3b736_row5_col6, #T_3b736_row5_col7, #T_3b736_row6_col0, #T_3b736_row6_col1, #T_3b736_row6_col2, #T_3b736_row6_col3, #T_3b736_row6_col4, #T_3b736_row6_col5, #T_3b736_row6_col6, #T_3b736_row6_col7, #T_3b736_row7_col0, #T_3b736_row7_col1, #T_3b736_row7_col2, #T_3b736_row7_col3, #T_3b736_row7_col4, #T_3b736_row7_col5, #T_3b736_row7_col6, #T_3b736_row7_col7, #T_3b736_row8_col0, #T_3b736_row8_col1, #T_3b736_row8_col2, #T_3b736_row8_col3, #T_3b736_row8_col4, #T_3b736_row8_col5, #T_3b736_row8_col6, #T_3b736_row8_col7, #T_3b736_row9_col0, #T_3b736_row9_col1, #T_3b736_row9_col2, #T_3b736_row9_col3, #T_3b736_row9_col4, #T_3b736_row9_col5, #T_3b736_row9_col6, #T_3b736_row9_col7, #T_3b736_row10_col0, #T_3b736_row10_col1, #T_3b736_row10_col2, #T_3b736_row10_col3, #T_3b736_row10_col4, #T_3b736_row10_col5, #T_3b736_row10_col6, #T_3b736_row10_col7, #T_3b736_row11_col0, #T_3b736_row11_col1, #T_3b736_row11_col2, #T_3b736_row11_col3, #T_3b736_row11_col4, #T_3b736_row11_col5, #T_3b736_row11_col6, #T_3b736_row11_col7, #T_3b736_row12_col0, #T_3b736_row12_col1, #T_3b736_row12_col2, #T_3b736_row12_col3, #T_3b736_row12_col4, #T_3b736_row12_col5, #T_3b736_row12_col6, #T_3b736_row12_col7, #T_3b736_row13_col0, #T_3b736_row13_col1, #T_3b736_row13_col2, #T_3b736_row13_col3, #T_3b736_row13_col4, #T_3b736_row13_col5, #T_3b736_row13_col6, #T_3b736_row13_col7 {
#   text-align: left;
# }
# #T_3b736_row0_col1, #T_3b736_row0_col2, #T_3b736_row0_col6, #T_3b736_row0_col7, #T_3b736_row1_col3, #T_3b736_row1_col4, #T_3b736_row1_col5, #T_3b736_row1_col7, #T_3b736_row2_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_3b736_row0_col8, #T_3b736_row1_col8, #T_3b736_row2_col8, #T_3b736_row3_col8, #T_3b736_row4_col8, #T_3b736_row5_col8, #T_3b736_row6_col8, #T_3b736_row7_col8, #T_3b736_row8_col8, #T_3b736_row9_col8, #T_3b736_row10_col8, #T_3b736_row11_col8, #T_3b736_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_3b736_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_3b736">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3b736_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3b736_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_3b736_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_3b736_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_3b736_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_3b736_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_3b736_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_3b736_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_3b736_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b736_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_3b736_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_3b736_row0_col1" class="data row0 col1" >0.7667</td>
#       <td id="T_3b736_row0_col2" class="data row0 col2" >0.8500</td>
#       <td id="T_3b736_row0_col3" class="data row0 col3" >0.7000</td>
#       <td id="T_3b736_row0_col4" class="data row0 col4" >0.6000</td>
#       <td id="T_3b736_row0_col5" class="data row0 col5" >0.6333</td>
#       <td id="T_3b736_row0_col6" class="data row0 col6" >0.5300</td>
#       <td id="T_3b736_row0_col7" class="data row0 col7" >0.5500</td>
#       <td id="T_3b736_row0_col8" class="data row0 col8" >0.0310</td>
#     </tr>
#     <tr>
#       <th id="T_3b736_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_3b736_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_3b736_row1_col1" class="data row1 col1" >0.7500</td>
#       <td id="T_3b736_row1_col2" class="data row1 col2" >0.8000</td>
#       <td id="T_3b736_row1_col3" class="data row1 col3" >0.9000</td>
#       <td id="T_3b736_row1_col4" class="data row1 col4" >0.6500</td>
#       <td id="T_3b736_row1_col5" class="data row1 col5" >0.7333</td>
#       <td id="T_3b736_row1_col6" class="data row1 col6" >0.5200</td>
#       <td id="T_3b736_row1_col7" class="data row1 col7" >0.5500</td>
#       <td id="T_3b736_row1_col8" class="data row1 col8" >0.0720</td>
#     </tr>
#     <tr>
#       <th id="T_3b736_level0_row2" class="row_heading level0 row2" >dt</th>
#       <td id="T_3b736_row2_col0" class="data row2 col0" >Decision Tree Classifier</td>
#       <td id="T_3b736_row2_col1" class="data row2 col1" >0.7000</td>
#       <td id="T_3b736_row2_col2" class="data row2 col2" >0.7250</td>
#       <td id="T_3b736_row2_col3" class="data row2 col3" >0.9000</td>
#       <td id="T_3b736_row2_col4" class="data row2 col4" >0.6000</td>
#       <td id="T_3b736_row2_col5" class="data row2 col5" >0.7000</td>
#       <td id="T_3b736_row2_col6" class="data row2 col6" >0.4200</td>
#       <td id="T_3b736_row2_col7" class="data row2 col7" >0.4500</td>
#       <td id="T_3b736_row2_col8" class="data row2 col8" >0.0200</td>
#     </tr>
#     <tr>
#       <th id="T_3b736_level0_row3" class="row_heading level0 row3" >svm</th>
#       <td id="T_3b736_row3_col0" class="data row3 col0" >SVM - Linear Kernel</td>
#       <td id="T_3b736_row3_col1" class="data row3 col1" >0.7000</td>
#       <td id="T_3b736_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_3b736_row3_col3" class="data row3 col3" >0.5000</td>
#       <td id="T_3b736_row3_col4" class="data row3 col4" >0.4000</td>
#       <td id="T_3b736_row3_col5" class="data row3 col5" >0.4333</td>
#       <td id="T_3b736_row3_col6" class="data row3 col6" >0.3800</td>
#       <td id="T_3b736_row3_col7" class="data row3 col7" >0.4000</td>
#       <td id="T_3b736_row3_col8" class="data row3 col8" >0.0210</td>
#     </tr>
#     <tr>
#       <th id="T_3b736_level0_row4" class="row_heading level0 row4" >ridge</th>
#       <td id="T_3b736_row4_col0" class="data row4 col0" >Ridge Classifier</td>
#       <td id="T_3b736_row4_col1" class="data row4 col1" >0.6667</td>
#       <td id="T_3b736_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_3b736_row4_col3" class="data row4 col3" >0.6000</td>
#       <td id="T_3b736_row4_col4" class="data row4 col4" >0.4500</td>
#       <td id="T_3b736_row4_col5" class="data row4 col5" >0.5000</td>
#       <td id="T_3b736_row4_col6" class="data row4 col6" >0.3300</td>
#       <td id="T_3b736_row4_col7" class="data row4 col7" >0.3500</td>
#       <td id="T_3b736_row4_col8" class="data row4 col8" >0.0210</td>
#     </tr>
#     <tr>
#       <th id="T_3b736_level0_row5" class="row_heading level0 row5" >lda</th>
#       <td id="T_3b736_row5_col0" class="data row5 col0" >Linear Discriminant Analysis</td>
#       <td id="T_3b736_row5_col1" class="data row5 col1" >0.6667</td>
#       <td id="T_3b736_row5_col2" class="data row5 col2" >0.8000</td>
#       <td id="T_3b736_row5_col3" class="data row5 col3" >0.6000</td>
#       <td id="T_3b736_row5_col4" class="data row5 col4" >0.4500</td>
#       <td id="T_3b736_row5_col5" class="data row5 col5" >0.5000</td>
#       <td id="T_3b736_row5_col6" class="data row5 col6" >0.3300</td>
#       <td id="T_3b736_row5_col7" class="data row5 col7" >0.3500</td>
#       <td id="T_3b

# %%
s.evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
s.plot_model(best, plot = 'confusion_matrix')

# %%
s.predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6bb7d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6bb7d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6bb7d_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_6bb7d_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_6bb7d_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_6bb7d_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_6bb7d_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_6bb7d_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_6bb7d_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6bb7d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6bb7d_row0_col0" class="data row0 col0" >Ada Boost Classifier</td>
#       <td id="T_6bb7d_row0_col1" class="data row0 col1" >0.3636</td>
#       <td id="T_6bb7d_row0_col2" class="data row0 col2" >0.2667</td>
#       <td id="T_6bb7d_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_6bb7d_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_6bb7d_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_6bb7d_row0_col6" class="data row0 col6" >-0.3509</td>
#       <td id="T_6bb7d_row0_col7" class="data row0 col7" >-0.4303</td>
#     </tr>
#   </tbody>
# </table>
#      is_home  curr_xG  opp_xG  curr_shots  opp_shots  curr_corner  opp_corner  \
# 93         1     1.67    1.60          27         16            7           8
# 109        1     1.43    0.54          19         13            7           4
# 376        1     2.59    0.73          18         13            3           3
# 169        1     1.24    1.52          16         14            2           1
# 429        0     1.43    1.41          17         10            6           6
# 439        0     0.81    1.88           8         15            1           3
# 432        0     1.05    1.63          10         20            6           6
# 431        0     1.17    1.22           5         17            5           3
# 325        1     1.49    1.33          19         17            6           9
# 129        1     0.49    1.08          10         16            6           2
# 244        1     1.30    1.07          11         13            3           7
#
#      curr_PK_Goal  opp_PK_Goal  curr_PK_shots  opp_PK_shots  possesion  \
# 93              0            0              0             0       0.46
# 109             0            0              0             0       0.42
# 376             0            0              1             0       0.72
# 169             0            0              1             0       0.61
# 429             0            0              0             0       0.44
# 439             0            0              1             0       0.40
# 432             0            0              0             0       0.38
# 431             0            0              0             0       0.50
# 325             0            0              0             1       0.48
# 129             0            0              0             0       0.63
# 244             0            0              1             0       0.55
#
#      Winner  prediction_label  prediction_score
# 93    False                 0            0.6576
# 109    True                 0            0.8788
# 376    True                 0            0.7476
# 169   False                 1            0.5859
# 429    True                 0            0.8402
# 439   False                 0            0.7536
# 432   False                 0            0.7985
# 431    True                 0            0.7059
# 325    True                 0            0.6282
# 129   False                 0            0.6931
# 244   False                 1            0.6863

# %%
predictions = s.predict_model(best, data=X_test, raw_score=True)
predictions
# Out:
# <style type="text/css">
# </style>
# <table id="T_1fad6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1fad6_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1fad6_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_1fad6_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_1fad6_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_1fad6_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_1fad6_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_1fad6_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_1fad6_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1fad6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1fad6_row0_col0" class="data row0 col0" >Ada Boost Classifier</td>
#       <td id="T_1fad6_row0_col1" class="data row0 col1" >0.9350</td>
#       <td id="T_1fad6_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_1fad6_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_1fad6_row0_col4" class="data row0 col4" >0.8850</td>
#       <td id="T_1fad6_row0_col5" class="data row0 col5" >0.9390</td>
#       <td id="T_1fad6_row0_col6" class="data row0 col6" >0.8700</td>
#       <td id="T_1fad6_row0_col7" class="data row0 col7" >0.8774</td>
#     </tr>
#   </tbody>
# </table>
#      is_home  curr_xG  opp_xG  curr_shots  opp_shots  curr_corner  opp_corner  \
# 0          0     0.81    1.88           8         15            1           3
# 1          0     0.54    1.93           9         15            4           3
# 2          0     0.86    1.36           6         11            7           3
# 3          0     0.81    1.88           8         15            1           3
# 4          1     1.20    1.20          17         20            6           4
# ..       ...      ...     ...         ...        ...          ...         ...
# 195        0     0.99    2.07          16         16            5           3
# 196        0     0.99    2.07          16         16            5           3
# 197        0     0.99    2.07          16         16            5           3
# 198        0     0.99    2.07          16         16            5           3
# 199        1     2.33    0.11          30          3            8           4
#
#      curr_PK_Goal  opp_PK_Goal  curr_PK_shots  opp_PK_shots  possesion  \
# 0               0            0              1             0       0.40
# 1               0            0              0             0       0.38
# 2               0            0              0             0       0.47
# 3               0            0              1             0       0.40
# 4               0            0              0             0       0.49
# ..            ...          ...            ...           ...        ...
# 195             0            0              0             0       0.29
# 196             0            0              0             0       0.29
# 197             0            0              0             0       0.29
# 198             0            0              0             0       0.29
# 199             0            0              1             0       0.46
#
#      Winner  prediction_label  prediction_score_0  prediction_score_1
# 0     False                 0              0.7536              0.2464
# 1     False                 0              0.7896              0.2104
# 2     False                 0              0.7692              0.2308
# 3     False                 0              0.7536              0.2464
# 4     False                 0              0.7513              0.2487
# ..      ...               ...                 ...                 ...
# 195    True                 1              0.2718              0.7282
# 196    True                 1              0.2718              0.7282
# 197    True                 1              0.2718              0.7282
# 198    True                 1              0.2718              0.7282
# 199    True                 1              0.3080              0.6920
#
# [200 rows x 16 columns]

# %%
# Show confusion matrix for predictions
conf_matrix = confusion_matrix(predictions['Winner'], predictions['prediction_label'])
sns.heatmap(conf_matrix, annot=True)
# Out:
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# <AxesSubplot: >
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
